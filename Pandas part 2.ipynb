# %%
import pandas as pd
import numpy as np

# %%
os.chdir(r'C:\Users\FUTURE\Documents\examples')

# %%
df = pd.read_csv('l1.csv')

# %%
df
# Out:
#   num1 num2  pair1  pair2
# 0  one    a      1      2
# 1  one    b      3      4
# 2  one    c      5      6
# 3  one    d      7      8
# 4  two    a      9     10
# 5  two    b     11     12
# 6  two    c     13     14
# 7  two    d     15     16

# %%
df = pd.read_csv('l1.csv', index_col = ['num1'])

# %%
df
# Out:
#      num2  pair1  pair2
# num1
# one     a      1      2
# one     b      3      4
# one     c      5      6
# one     d      7      8
# two     a      9     10
# two     b     11     12
# two     c     13     14
# two     d     15     16

# %%
df = pd.read_csv('l1.csv', index_col = ['num1','num2'])

# %%
df
# Out:
#            pair1  pair2
# num1 num2
# one  a         1      2
#      b         3      4
#      c         5      6
#      d         7      8
# two  a         9     10
#      b        11     12
#      c        13     14
#      d        15     16

# %%
df1 = pd.read_csv('junk.csv')

# %%
df1
# Out:
#                        # hello1! Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0                              a          b          c          d    message
# 1  # IEFGlobal is a global body         NaN        NaN        NaN        NaN
# 2     #machine learning python r        NaN        NaN        NaN        NaN
# 3                              1          2          3          4      hello
# 4                              5          6          7          8      world
# 5                              9         10         11         12        foo

# %%
df1 = pd.read_csv('junk.csv', header = None, skiprows = [0,2,3])

# %%
df1
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
df2 = pd.read_html('https://www.baseball-reference.com/postseason/2017_ALDS1.shtml')

# %%
df2
# Out:
# [                   0                  1                  2
#  0  Game 1, October 5  Game 1, October 5  Game 1, October 5
#  1   New York Yankees                  0              Final
#  2  Cleveland Indians                  4                NaN,
#     0                   1
#  0  W  Trevor Bauer (1-0)
#  1  L    Sonny Gray (0-1)
#  2  S      Cody Allen (1),
#                     0                  1                  2
#  0  Game 2, October 6  Game 2, October 6  Game 2, October 6
#  1   New York Yankees                  8              Final
#  2  Cleveland Indians                  9               (13),
#     0                      1
#  0  W      Josh Tomlin (1-0)
#  1  L  Dellin Betances (0-1),
#                     0                  1                  2
#  0  Game 3, October 8  Game 3, October 8  Game 3, October 8
#  1  Cleveland Indians                  0              Final
#  2   New York Yankees                  1                NaN,
#     0                      1
# ...

# %%
len(df2)
# Out:
# 12

# %%
type(df2)
# Out:
# list

# %%
df2[0]
# Out:
#                    0                  1                  2
# 0  Game 1, October 5  Game 1, October 5  Game 1, October 5
# 1   New York Yankees                  0              Final
# 2  Cleveland Indians                  4                NaN
